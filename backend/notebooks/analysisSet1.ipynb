# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, precision_score
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
from sklearn.metrics import f1_score, roc_auc_score
from scipy.stats import skew
from scipy.stats import kurtosis
from scipy.stats import pearsonr

# %% [markdown]
# ## Dataset loading - ucitavanje dataseta

# %%
df=pd.read_csv('../data/dataset.csv')

# %% [markdown]
# ## Display info about data and first five columns - prikaz informacija o datasetu i prvih 5 kolona iz dataseta

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   dob                       1205 non-null   int64
#  1   sistolicki_krvni_tlak     1200 non-null   float64
#  2   dijastolicki_krvni_tlak   1201 non-null   float64
#  3   glukoza_u_krvi            1203 non-null   float64
#  4   tjelesna_temp             1205 non-null   int64
#  5   BMI                       1187 non-null   float64
#  6   komplikacije_u_proslosti  1203 non-null   float64
#  7   dijabetes                 1203 non-null   float64
#  8   gestacijski_dijabetes     1205 non-null   int64
#  9   mentalno_zdravlje         1205 non-null   int64
#  10  otkucaji_srca             1203 non-null   float64
#  11  nivo_rizika               1187 non-null   object
# dtypes: float64(7), int64(4), object(1)
# memory usage: 113.1+ KB

# %%
df.head()
# Out:
#    dob  sistolicki_krvni_tlak  dijastolicki_krvni_tlak  glukoza_u_krvi  \
# 0   22                   90.0                     60.0             9.0
# 1   22                  110.0                     70.0             7.1
# 2   27                  110.0                     70.0             7.5
# 3   20                  100.0                     70.0             7.2
# 4   20                   90.0                     60.0             7.5
#
#    tjelesna_temp   BMI  komplikacije_u_proslosti  dijabetes  \
# 0            100  18.0                       1.0        1.0
# 1             98  20.4                       0.0        0.0
# 2             98  23.0                       1.0        0.0
# 3             98  21.2                       0.0        0.0
# 4             98  19.7                       0.0        0.0
#
#    gestacijski_dijabetes  mentalno_zdravlje  otkucaji_srca nivo_rizika
# 0                      0                  1           80.0        High
# ...

# %% [markdown]
# ## Converting Farenheit into Celsius - pretvaranje Farenhajta u stepene Celzijusove skale

# %%
df['tjelesna_temp'] = ((df['tjelesna_temp'] - 32) * 5/9).round(2)

# %%
df.head()
# Out:
#    dob  sistolicki_krvni_tlak  dijastolicki_krvni_tlak  glukoza_u_krvi  \
# 0   22                   90.0                     60.0             9.0
# 1   22                  110.0                     70.0             7.1
# 2   27                  110.0                     70.0             7.5
# 3   20                  100.0                     70.0             7.2
# 4   20                   90.0                     60.0             7.5
#
#    tjelesna_temp   BMI  komplikacije_u_proslosti  dijabetes  \
# 0          37.78  18.0                       1.0        1.0
# 1          36.67  20.4                       0.0        0.0
# 2          36.67  23.0                       1.0        0.0
# 3          36.67  21.2                       0.0        0.0
# 4          36.67  19.7                       0.0        0.0
#
#    gestacijski_dijabetes  mentalno_zdravlje  otkucaji_srca nivo_rizika
# 0                      0                  1           80.0        High
# ...

# %%
df['nivo_rizika'].unique()
# Out:
# array(['High', 'Low', nan], dtype=object)

# %%
kategoricke_varijable = ['komplikacije_u_proslosti', 'dijabetes', 
                         'gestacijski_dijabetes', 'mentalno_zdravlje']

if 'nivo_rizika' in df.columns:
    # Čišćenje NaN vrijednosti u nivo_rizika jer su bitne za analizu - Cleaning rows with NaN in 'nivo_rizika'
    df_clean = df.dropna(subset=['nivo_rizika'])
    
    # Postavljanje grida - Grid setup
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    axes = axes.flatten()
    
    for idx, var in enumerate(kategoricke_varijable):
        if idx < len(axes):
            # Redovi su nivo_rizika, stupci su vrijednosti varijable (npr. 0 i 1)
            crosstab = pd.crosstab(df_clean['nivo_rizika'], df_clean[var], normalize='index') * 100
            
            # Iscrtavanje - Plotting
            crosstab.plot(kind='bar', stacked=True, ax=axes[idx], 
                          colormap='Pastel1', edgecolor='black')
            
            axes[idx].set_title(f'Utjecaj: {var}', fontweight='bold')
            axes[idx].set_xlabel('Nivo rizika')
            axes[idx].set_ylabel('Procenat (%)')
            axes[idx].legend(title=var, bbox_to_anchor=(1.05, 1), loc='upper left')
            axes[idx].grid(True, alpha=0.3, axis='y')
            axes[idx].tick_params(axis='x', rotation=0)

    plt.suptitle('Distribucija faktora prema nivou rizika trudnoće', fontsize=16, fontweight='bold')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %% [markdown]
# ## Displaying the number of missing values related to each variable
# ## Prikaz broja nedostajućih vrijednosti za svaku varijablu

# %%
print(df.isnull().sum())
# Out:
# dob                          0
# sistolicki_krvni_tlak        5
# dijastolicki_krvni_tlak      4
# glukoza_u_krvi               2
# tjelesna_temp                0
# BMI                         18
# komplikacije_u_proslosti     2
# dijabetes                    2
# gestacijski_dijabetes        0
# mentalno_zdravlje            0
# otkucaji_srca                2
# nivo_rizika                 18
# dtype: int64

# %% [markdown]
# ## Calculating skewness for numerical variables
# ## Računanje asimetrije (skewness) za numeričke varijable

# %%
varijable = [
    'sistolicki_krvni_tlak',
    'dijastolicki_krvni_tlak',
    'glukoza_u_krvi',
    'BMI',
    'komplikacije_u_proslosti',
    'dijabetes',
    'otkucaji_srca'
]


skewness_values = {}
for var in varijable:
    if var in df.columns:
       
        podaci = df[var].dropna()
        
        
        if pd.api.types.is_numeric_dtype(podaci):
            skewness_values[var] = skew(podaci)
        else:
            print(f"Varijabla '{var}' nije numerička. Skewness se ne računa.")
            skewness_values[var] = None
    else:
        print(f"Varijabla '{var}' ne postoji u DataFrame-u.")
        skewness_values[var] = None


print("\nKoeficijent iskrivljenosti (skewness):")
for var, sk in skewness_values.items():
    if sk is not None:
        print(f"{var}: {sk:.4f}")
    else:
        print(f"{var}: nije izračunat")
# Out:
# Koeficijent iskrivljenosti (skewness):
# sistolicki_krvni_tlak: 0.2571
# dijastolicki_krvni_tlak: 0.3772
# glukoza_u_krvi: 1.5781
# BMI: 0.4574
# komplikacije_u_proslosti: 1.7071
# dijabetes: 0.9339
# otkucaji_srca: 0.2097

# %% [markdown]
# ## Filling the missing values of numerical variables with mean and median
# ## Popunjavanje nedostajućih vrijednosti za numeričke varijable putem mean i median vrijednosti

# %%
skewness_dict = {
    'sistolicki_krvni_tlak': 0.2571,
    'dijastolicki_krvni_tlak': 0.3772,
    'glukoza_u_krvi': 1.5781,
    'BMI': 0.4574,
    'komplikacije_u_proslosti': 1.7071,
    'dijabetes': 0.9339,
    'otkucaji_srca': 0.2097
}

for var, skew_val in skewness_dict.items():
    if var not in df.columns:
        print(f"Varijabla '{var}' ne postoji u DataFrame-u.")
        continue
    
    if skew_val < -1 or skew_val > 1:
        fill_value = df[var].median(skipna=True)
        method = "median"
    else:
        fill_value = df[var].mean(skipna=True)
        method = "mean"
    
    df[var] = df[var].fillna(fill_value)
    
    print(f"{var}: skew={skew_val:.4f} → popunjeno sa {method} = {fill_value:.4f}")

print("\nPreostale missing vrijednosti:")
print(df[list(skewness_dict.keys())].isnull().sum())
# Out:
# sistolicki_krvni_tlak: skew=0.2571 → popunjeno sa mean = 116.8192
# dijastolicki_krvni_tlak: skew=0.3772 → popunjeno sa mean = 77.1665
# glukoza_u_krvi: skew=1.5781 → popunjeno sa median = 6.9000
# BMI: skew=0.4574 → popunjeno sa mean = 23.3151
# komplikacije_u_proslosti: skew=1.7071 → popunjeno sa median = 0.0000
# dijabetes: skew=0.9339 → popunjeno sa mean = 0.2884
# otkucaji_srca: skew=0.2097 → popunjeno sa mean = 75.8171
#
# Preostale missing vrijednosti:
# sistolicki_krvni_tlak       0
# dijastolicki_krvni_tlak     0
# glukoza_u_krvi              0
# BMI                         0
# komplikacije_u_proslosti    0
# dijabetes                   0
# otkucaji_srca               0
# dtype: int64

# %% [markdown]
# ## Droping the rows with missing value for "nivo rizika" -> label column
# ## Brisanje redova u kojima nedostaju vrijednosti za nivo rizika

# %%
print(df['nivo_rizika'].value_counts(dropna=False))
# Out:
# nivo_rizika
# Low     713
# High    474
# NaN      18
# Name: count, dtype: int64

# %%
df = df.dropna(subset=['nivo_rizika'])

# %% [markdown]
# ## Encoding categorical columns
# ## Enkodiranje kategoričkih varijabli

# %%
encoder = LabelEncoder()

# %%
df['nivo_rizika'].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
df['nivo_rizika'] = df['nivo_rizika'].map({'High':1, 'Low':0})

# %%
df.head()
# Out:
#    dob  sistolicki_krvni_tlak  dijastolicki_krvni_tlak  glukoza_u_krvi  \
# 0   22                   90.0                     60.0             9.0
# 1   22                  110.0                     70.0             7.1
# 2   27                  110.0                     70.0             7.5
# 3   20                  100.0                     70.0             7.2
# 4   20                   90.0                     60.0             7.5
#
#    tjelesna_temp   BMI  komplikacije_u_proslosti  dijabetes  \
# 0          37.78  18.0                       1.0        1.0
# 1          36.67  20.4                       0.0        0.0
# 2          36.67  23.0                       1.0        0.0
# 3          36.67  21.2                       0.0        0.0
# 4          36.67  19.7                       0.0        0.0
#
#    gestacijski_dijabetes  mentalno_zdravlje  otkucaji_srca  nivo_rizika
# 0                      0                  1           80.0            1
# ...

# %% [markdown]
# ## Descriptive statistic
# ## Deskriptivna statistika

# %%
df.describe()
# Out:
#                dob  sistolicki_krvni_tlak  dijastolicki_krvni_tlak  \
# count  1187.000000            1187.000000              1187.000000
# mean     27.764111             116.841008                77.208368
# std      12.645309              18.663392                14.262284
# min      10.000000              70.000000                40.000000
# 25%      21.000000             100.000000                65.000000
# 50%      25.000000             120.000000                80.000000
# 75%      32.000000             130.000000                90.000000
# max     325.000000             200.000000               140.000000
#
#        glukoza_u_krvi  tjelesna_temp          BMI  komplikacije_u_proslosti  \
# count     1187.000000    1187.000000  1187.000000               1187.000000
# mean         7.515906      36.889840    23.339521                  0.176917
# std          3.051976       0.604018     3.860646                  0.381759
# ...

# %% [markdown]
# ### Droping the raw with outlier value for "dob" column -> 325
# ### Brisanje reda gdje je vrijednost za dob 325

# %%
indeksi_za_izbacivanje = df[df['dob'] == 325].index

df.drop(indeksi_za_izbacivanje, inplace=True)

# %%
print(df['dob'].max())
# Out:
# 65

# %%
df['dob'].unique()
# Out:
# array([22, 27, 20, 23, 26, 25, 19, 18, 24, 21, 44, 17, 28, 40, 37, 29, 34,
#        35, 36, 32, 38, 48, 30, 39, 31, 33, 41, 42, 15, 50, 63, 55, 49, 16,
#        12, 60, 65, 43, 13, 54, 10, 45])

# %%
print(df[(df['dob'] < 15) | (df['dob'] > 50)].shape[0])
# Out:
# 46

# %% [markdown]
# ### Considering the fact that the range for variable age is between 10 and 65, it is decided to keep data between 15 and 50.
# ### Uzimajući u obzir da je opseg varijable dob između 10 i 65, odlučeno je da se zadrže samo podaci koji su između 15 i 50 godina starosti

# %%
df = df[(df['dob'] >= 15) & (df['dob'] <= 50)]

print(f"Broj redova nakon čišćenja: {len(df)}")
# Out:
# Broj redova nakon čišćenja: 1140

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1140 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   dob                       1140 non-null   int64
#  1   sistolicki_krvni_tlak     1140 non-null   float64
#  2   dijastolicki_krvni_tlak   1140 non-null   float64
#  3   glukoza_u_krvi            1140 non-null   float64
#  4   tjelesna_temp             1140 non-null   float64
#  5   BMI                       1140 non-null   float64
#  6   komplikacije_u_proslosti  1140 non-null   float64
#  7   dijabetes                 1140 non-null   float64
#  8   gestacijski_dijabetes     1140 non-null   int64
#  9   mentalno_zdravlje         1140 non-null   int64
#  10  otkucaji_srca             1140 non-null   float64
#  11  nivo_rizika               1140 non-null   int64
# dtypes: float64(8), int64(4)
# memory usage: 115.8 KB

# %% [markdown]
# ## Calculating the kurtosis value for numerical variables
# ## Računanje zaobljenosti (kurtosis) za numeričke varijable

# %%
varijable = [
    'sistolicki_krvni_tlak',
    'dijastolicki_krvni_tlak',
    'glukoza_u_krvi',
    'BMI',
    'komplikacije_u_proslosti',
    'dijabetes',
    'otkucaji_srca'
]

kurtosis_values = {}
for var in varijable:
    if var in df.columns:
        podaci = df[var].dropna()
        
        if pd.api.types.is_numeric_dtype(podaci):
            kurtosis_values[var] = kurtosis(podaci, fisher=True)
        else:
            print(f"Varijabla '{var}' nije numerička. Kurtosis se ne računa.")
            kurtosis_values[var] = None
    else:
        print(f"Varijabla '{var}' ne postoji u DataFrame-u.")
        kurtosis_values[var] = None

print("\nKoeficijent kurtosisa (Fisher, excess kurtosis):")
print("(0 = normalna distribucija, >0 = oštriji vrh, <0 = plosnatiji vrh)")
for var, kurt in kurtosis_values.items():
    if kurt is not None:
        print(f"{var}: {kurt:.4f}")
    else:
        print(f"{var}: nije izračunat")
# Out:
# Koeficijent kurtosisa (Fisher, excess kurtosis):
# (0 = normalna distribucija, >0 = oštriji vrh, <0 = plosnatiji vrh)
# sistolicki_krvni_tlak: 0.4394
# dijastolicki_krvni_tlak: -0.2885
# glukoza_u_krvi: 2.7801
# BMI: 1.3348
# komplikacije_u_proslosti: 0.7291
# dijabetes: -1.1214
# otkucaji_srca: -0.1696

# %%
print(df.isnull().sum())
# Out:
# dob                         0
# sistolicki_krvni_tlak       0
# dijastolicki_krvni_tlak     0
# glukoza_u_krvi              0
# tjelesna_temp               0
# BMI                         0
# komplikacije_u_proslosti    0
# dijabetes                   0
# gestacijski_dijabetes       0
# mentalno_zdravlje           0
# otkucaji_srca               0
# nivo_rizika                 0
# dtype: int64

# %% [markdown]
# ## Histograms for numeric variables
# ## Prikaz histograma za numeričke varijable

# %%
numericke_za_graf = [
    'dob',
    'sistolicki_krvni_tlak',
    'dijastolicki_krvni_tlak',
    'glukoza_u_krvi',
    'tjelesna_temp',
    'BMI',
    'komplikacije_u_proslosti',
    'dijabetes',
    'gestacijski_dijabetes',
    'mentalno_zdravlje',
    'otkucaji_srca'
]

postojece = [var for var in numericke_za_graf if var in df.columns]
if len(postojece) != len(numericke_za_graf):
    print("Upozorenje: sljedeće varijable ne postoje u DataFrame-u:")
    print(set(numericke_za_graf) - set(postojece))

df[postojece].hist(bins=15, figsize=(15, 10), layout=(4, 3), 
                   color='skyblue', edgecolor='black')
plt.suptitle('Raspodjela numeričkih varijabli – histogrami', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# --- Density plot (KDE) - Kernel Density Estimation (procenjivanje gustine raspodele pomoću jezgra) ---
kontinuirane = ['dob', 'sistolicki_krvni_tlak', 'dijastolicki_krvni_tlak', 
                'glukoza_u_krvi', 'tjelesna_temp', 'BMI', 
                'otkucaji_srca']
kontinuirane = [var for var in kontinuirane if var in df.columns]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()
for i, var in enumerate(kontinuirane):
    sns.histplot(df[var], kde=True, bins=20, ax=axes[i], color='coral')
    axes[i].set_title(var)
    
for j in range(len(kontinuirane), len(axes)):
    axes[j].set_visible(False)
plt.suptitle('Distribucija s KDE (procjena gustoće vjerojatnosti)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pie chart for categorical variable - "level of risk"
# ## Prikaz "pie chart-a" za kategoričku varijablu -> nivo_rizika

# %%
df['nivo_rizika'].unique()
# Out:
# array([1, 0])

# %%
podaci = df['nivo_rizika'].dropna()
podaci.value_counts().plot(kind='pie', autopct='%1.1f%%', 
                           colors=['#66b3ff','#ff9999',], 
                           startangle=90, explode=(0.05, 0))
plt.title('Distribucija nivoa rizika (bez missing vrijednosti)')
plt.ylabel('')  
plt.show()

# %% [markdown]
# ## Correlation matrix
# ## Korelacijska matrica

# %%
correlation_matrix = df.corr(method='pearson')
print(correlation_matrix)
# Out:
#                                dob  sistolicki_krvni_tlak  \
# dob                       1.000000               0.272058
# sistolicki_krvni_tlak     0.272058               1.000000
# dijastolicki_krvni_tlak   0.247684               0.789834
# glukoza_u_krvi            0.631303               0.325386
# tjelesna_temp            -0.092631              -0.174061
# BMI                       0.351126               0.278045
# komplikacije_u_proslosti  0.268233               0.130432
# dijabetes                 0.268564               0.145549
# gestacijski_dijabetes    -0.048826               0.130213
# mentalno_zdravlje         0.142593               0.181586
# otkucaji_srca             0.161900               0.147213
# nivo_rizika               0.215524               0.272855
#
#                           dijastolicki_krvni_tlak  glukoza_u_krvi  \
# dob                                      0.247684        0.631303
# sistolicki_krvni_tlak                    0.789834        0.325386
# ...

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Korelacijska matrica varijabli trudnoće')
plt.show()

# %% [markdown]
# p-value

# %%
def korelacija_sa_p_vrijednostima(df, varijable=None):
    
    # Ako su varijable specificirane, uzmi samo njih - otherwise use all numeric columns
    if varijable is not None:
        df_analiza = df[varijable].copy()
    else:
        df_analiza = df.copy()
    
    # Uklanjanje redova sa NaN vrijednostima - Dropping rows with NaN values for accurate correlation analysis
    df_clean = df_analiza.dropna()
    
    print(f"\n Analizirano {df_clean.shape[0]} redova (uklonjeno {df_analiza.shape[0] - df_clean.shape[0]} redova sa NaN)")
    
    varijable_lista = df_clean.columns
    n = len(varijable_lista)
    
    corr_matrica = np.zeros((n, n))
    p_matrica = np.zeros((n, n))
    
    for i in range(n):
        for j in range(n):
            r, p = pearsonr(df_clean.iloc[:, i], df_clean.iloc[:, j])
            corr_matrica[i, j] = r
            p_matrica[i, j] = p
    
    corr_df = pd.DataFrame(corr_matrica, index=varijable_lista, columns=varijable_lista)
    p_df = pd.DataFrame(p_matrica, index=varijable_lista, columns=varijable_lista)
    
    return corr_df, p_df

# DEFINISANJE VARIJABLI ZA ANALIZU - DEFINING VARIABLES FOR ANALYSIS
varijable_analiza = [
    'dob',
    'sistolicki_krvni_tlak',
    'dijastolicki_krvni_tlak', 
    'glukoza_u_krvi',
    'tjelesna_temp',
    'BMI',
    'komplikacije_u_proslosti',
    'dijabetes',
    'gestacijski_dijabetes',
    'mentalno_zdravlje',
    'otkucaji_srca',
    'nivo_rizika'
]

# RAČUNANJE KORELACIJE I P-VRIJEDNOSTI - CALCULATING CORRELATIONS AND P-VALUES
korelacije, p_vrijednosti = korelacija_sa_p_vrijednostima(df, varijable_analiza)
 
# PRIKAZ REZULTATA - DISPLAYING RESULTS
print("\n" + "="*80)
print("KORELACIJSKA MATRICA")
print("="*80)
print(korelacije.round(4))

print("\n" + "="*80)
print("P-VRIJEDNOSTI")
print("="*80)
print(p_vrijednosti.round(4))

# STATISTIČKI ZNAČAJNE KORELACIJE (p < 0.05) - STATISTICALLY SIGNIFICANT CORRELATIONS (p < 0.05)
print("\n" + "="*80)
print("ZNAČAJNE KORELACIJE (p < 0.05)")
print("="*80)

znacajne = []
for i in range(len(korelacije.columns)):
    for j in range(i+1, len(korelacije.columns)):
        p_val = p_vrijednosti.iloc[i, j]
        if p_val < 0.05:
            r_val = korelacije.iloc[i, j]
            znacajne.append((korelacije.columns[i], 
                            korelacije.columns[j], 
                            r_val, 
                            p_val))

if znacajne:
    for v1, v2, r, p in znacajne:
        zvjezdice = "***" if p < 0.001 else "**" if p < 0.01 else "*"
        print(f"{v1:25} — {v2:25}: r = {r:8.4f} {zvjezdice}, p = {p:.4f}")
else:
    print("Nema statistički značajnih korelacija na nivou p < 0.05")


# Korelacije Za nivo_rizika - Correlations with nivo_rizika
print("\n" + "="*80)
print("KORELACIJE SA NIVOM RIZIKA")
print("="*80)

if 'nivo_rizika' in korelacije.columns:
    for varijabla in korelacije.index:
        if varijabla != 'nivo_rizika':
            r = korelacije.loc[varijabla, 'nivo_rizika']
            p = p_vrijednosti.loc[varijabla, 'nivo_rizika']
            znacaj = "✓ ZNAČAJNO" if p < 0.05 else "✗ nije značajno"
            print(f"{varijabla:25} : r = {r:8.4f}, p = {p:.4f} {znacaj}")
# Out:
#  Analizirano 1140 redova (uklonjeno 0 redova sa NaN)
#
# ...
# KORELACIJSKA MATRICA
# ...
#                              dob  sistolicki_krvni_tlak  \
# dob                       1.0000                 0.2721
# sistolicki_krvni_tlak     0.2721                 1.0000
# dijastolicki_krvni_tlak   0.2477                 0.7898
# glukoza_u_krvi            0.6313                 0.3254
# tjelesna_temp            -0.0926                -0.1741
# BMI                       0.3511                 0.2780
# komplikacije_u_proslosti  0.2682                 0.1304
# dijabetes                 0.2686                 0.1455
# gestacijski_dijabetes    -0.0488                 0.1302
# mentalno_zdravlje         0.1426                 0.1816
# otkucaji_srca             0.1619                 0.1472
# nivo_rizika               0.2155                 0.2729
#
#                           dijastolicki_krvni_tlak  glukoza_u_krvi  \
# dob                                        0.2477          0.6313
# ...

# %% [markdown]
# The p-value is essential for distinguishing true relationships from random chance. Even a strong correlation (r = 0.95) is meaningless with a small sample size. In our analysis, nearly all p-values were < 0.05, confirming that our findings are reliable and generalizable.

# %% [markdown]
# A small p-value means the observed results are unlikely to occur by chance alone providing strong evidence against the null hypothesis.
# A large p-value suggests the results are consistent with random variation and do not provide enough evidence to reject the null hypothesis.

# %% [markdown]
# p-vrijednost je ključni statistički alat koji nam govori da li je uočena korelacija stvarna ili je nastala slučajno. Bez nje, čak i veoma jaka korelacija (npr. r = 0.95) može biti besmislena ako je uzorak mali.
#
# U gornjoj analizi, p-vrijednosti su pokazale da je gotovo svaka korelacija statistički značajna (p < 0.05), što znači da su naši zaključci pouzdani i ponovljivi na drugoj populaciji.

# %% [markdown]
# Mala p-vrijednost ukazuje da uočeni rezultati nisu vjerovatno rezultat slučajnosti, što predstavlja jak argument protiv nulte hipoteze. Nasuprot tome, velika p-vrijednost upućuje na to da se rezultati mogu objasniti slučajnim varijacijama, te nema dovoljno dokaza za odbacivanje nulte hipoteze.

# %% [markdown]
# ## Train and test split
# ## Dijeljenje dataseta na trening i test set

# %%
x = df.drop(columns=['nivo_rizika'])
y = df['nivo_rizika']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1140 entries, 0 to 1204
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   dob                       1140 non-null   int64
#  1   sistolicki_krvni_tlak     1140 non-null   float64
#  2   dijastolicki_krvni_tlak   1140 non-null   float64
#  3   glukoza_u_krvi            1140 non-null   float64
#  4   tjelesna_temp             1140 non-null   float64
#  5   BMI                       1140 non-null   float64
#  6   komplikacije_u_proslosti  1140 non-null   float64
#  7   dijabetes                 1140 non-null   float64
#  8   gestacijski_dijabetes     1140 non-null   int64
#  9   mentalno_zdravlje         1140 non-null   int64
#  10  otkucaji_srca             1140 non-null   float64
# dtypes: float64(8), int64(3)
# memory usage: 106.9 KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1140 entries, 0 to 1204
# Series name: nivo_rizika
# Non-Null Count  Dtype
# --------------  -----
# 1140 non-null   int64
# dtypes: int64(1)
# memory usage: 17.8 KB

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0, stratify=y)

# %% [markdown]
# This line splits the data into training and testing sets, with 20% of the data allocated for testing. The stratify=y parameter ensures that the class distribution in the target variable is preserved in both subsets, which is important for imbalanced classification problems.

# %% [markdown]
# Ova linija koda dijeli podatke na trening i test skupove, pri čemu se 20% podataka izdvaja za testiranje. Parametar stratify=y osigurava da omjer klasa u ciljnoj varijabli ostane isti u oba skupa, što je važno kod neuravnoteženih klasa.

# %%
y_test.value_counts()
# Out:
# nivo_rizika
# 0    136
# 1     92
# Name: count, dtype: int64

# %% [markdown]
# In the y_test set, we have 136 pregnant women with label 0 (low risk, normal condition) and 93 pregnant women with label 1 (increased risk). This indicates that the dataset is not too "skewed" to one side because there are enough examples for both healthy and high-risk cases.

# %% [markdown]
# U y_test skupu imamo 136 trudnica sa oznakom 0 (nizak rizik normalno stanje), a 93 trudnice sa oznakom 1 (povećan rizik). Ovo govori da dataset nije previše "nagnut" na jednu stranu jer postoji dovoljno primjera i za zdrave i za rizične slučajeve.

# %% [markdown]
# ## Data scaling

# %%
# Create properly scaled data using Pipeline to prevent data leakage
# (will be used in confusion matrix for SVM and k-NN)

# Kreiranje pravilno skaliranih podataka koristeći Pipeline za sprječavanje curenja podataka
# (koristit će se u matrici konfuzije za SVM i k-NN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)   
X_test_scaled = scaler.transform(x_test)


print(f"Unscaled data shape: x_train={x_train.shape}, x_test={x_test.shape}")
print(f"Scaled data shape: X_train_scaled={X_train_scaled.shape}, X_test_scaled={X_test_scaled.shape}")
# Out:
# Unscaled data shape: x_train=(912, 11), x_test=(228, 11)
# Scaled data shape: X_train_scaled=(912, 11), X_test_scaled=(228, 11)

# %% [markdown]
# ### Za k-NN i SVM koristimo skalirane podatke jer oni ovise o udaljenostima. Ostali algoritmi nisu osjetljivi na skaliranje

# %%
x_train
# Out:
#       dob  sistolicki_krvni_tlak  dijastolicki_krvni_tlak  glukoza_u_krvi  \
# 352    32                  100.0                     60.0             6.6
# 367    22                  120.0                     80.0             4.1
# 23     17                  120.0                     80.0             8.0
# 1136   41                  120.0                     85.0            17.0
# 112    36                  130.0                     90.0            17.0
# ...   ...                    ...                      ...             ...
# 436    18                  140.0                    100.0             3.7
# 108    26                  160.0                    100.0            11.0
# 932    21                  110.0                     80.0             5.1
# 327    18                  120.0                     70.0             3.5
# 246    30                  130.0                     70.0             6.0
#
#       tjelesna_temp   BMI  komplikacije_u_proslosti  dijabetes  \
# ...

# %% [markdown]
# ### Function for evaluating classification model
# ### Funkcija za evaluaciju klasifikacijskog modela

# %%
def evaluate_classifier(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None
    
    metrics = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "ROC AUC": roc_auc_score(y_test, y_proba) if y_proba is not None else None
    }
    return metrics, y_pred, y_proba

# %% [markdown]
# ### Function for evaluating regression model
# ### Funkcija za evaluaciju regresijskog modela

# %%
def evaluate_regressor(model, X_train, y_train_reg, X_test, y_test_reg):
    model.fit(X_train, y_train_reg)
    y_pred = model.predict(X_test)
    return {
        "MSE": mean_squared_error(y_test_reg, y_pred),
        "MAE": mean_absolute_error(y_test_reg, y_pred),
        "R2": r2_score(y_test_reg, y_pred)
    }

# %%
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "SVM (RBF)": SVC(probability=True, random_state=42),
    "k-NN (k=5)": KNeighborsClassifier(n_neighbors=5),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "Naive Bayes": GaussianNB()
}

results = {}
for name, clf in classifiers.items():
    print(f"\nEvaluacija: {name}")
    metrics, _, _ = evaluate_classifier(clf, x_train, y_train, x_test, y_test)
    results[name] = metrics
    for metric, value in metrics.items():
        if value is not None:
            print(f"  {metric}: {value:.4f}")
        else:
            print(f"  {metric}: nije podržan (nema predict_proba)")
# Out:
# Evaluacija: Logistic Regression
#   Accuracy: 0.9649
#   Precision: 1.0000
#   Recall: 0.9130
#   F1 Score: 0.9545
#   ROC AUC: 0.9967
#
# Evaluacija: Decision Tree
#   Accuracy: 0.9825
#   Precision: 0.9681
#   Recall: 0.9891
#   F1 Score: 0.9785
#   ROC AUC: 0.9835
#
# Evaluacija: Random Forest
#   Accuracy: 0.9912
#   Precision: 1.0000
#   Recall: 0.9783
#   F1 Score: 0.9890
#   ROC AUC: 0.9998
#
# Evaluacija: SVM (RBF)
#   Accuracy: 0.8991
#   Precision: 0.9600
#   Recall: 0.7826
#   F1 Score: 0.8623
#   ROC AUC: 0.9312
#
# Evaluacija: k-NN (k=5)
#   Accuracy: 0.9254
#   Precision: 0.9630
#   Recall: 0.8478
#   F1 Score: 0.9017
#   ROC AUC: 0.9383
#
# Evaluacija: Gradient Boosting
#   Accuracy: 0.9912
#   Precision: 1.0000
#   Recall: 0.9783
#   F1 Score: 0.9890
#   ROC AUC: 1.0000
#
# Evaluacija: Naive Bayes
#   Accuracy: 0.9605
#   Precision: 0.9882
#   Recall: 0.9130
#   F1 Score: 0.9492
#   ROC AUC: 0.9913

# %%
compare_df = pd.DataFrame(results).T
print("\n--- Usporedba algoritama (test set) ---")
print(compare_df)

# Sortiranje po F1 score
best_f1 = compare_df['F1 Score'].idxmax()
print(f"\nNajbolji algoritam po F1 score: {best_f1}")
# Out:
# --- Usporedba algoritama (test set) ---
#                      Accuracy  Precision    Recall  F1 Score   ROC AUC
# Logistic Regression  0.964912   1.000000  0.913043  0.954545  0.996723
# Decision Tree        0.982456   0.968085  0.989130  0.978495  0.983536
# Random Forest        0.991228   1.000000  0.978261  0.989011  0.999840
# SVM (RBF)            0.899123   0.960000  0.782609  0.862275  0.931186
# k-NN (k=5)           0.925439   0.962963  0.847826  0.901734  0.938339
# Gradient Boosting    0.991228   1.000000  0.978261  0.989011  1.000000
# Naive Bayes          0.960526   0.988235  0.913043  0.949153  0.991288
#
# Najbolji algoritam po F1 score: Random Forest

# %% [markdown]
# ### Confussion matrix
# ### Matrica konfuzije

# %%
# Use Pipelines for SVM and k-NN to ensure proper scaling without data leakage
# Korištenje Pipelines za SVM i k-NN kako bi se osiguralo pravilno skaliranje bez curenja podataka
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "SVM (RBF)": Pipeline([('scaler', StandardScaler()), ('svm', SVC(probability=True, random_state=42))]),
    "k-NN (k=5)": Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier(n_neighbors=5))]),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "Naive Bayes": GaussianNB()
}

data_for_model = {
    "Logistic Regression": (x_train, x_test),
    "Decision Tree": (x_train, x_test),
    "Random Forest": (x_train, x_test),
    "SVM (RBF)": (x_train, x_test),  # Pipeline handles scaling internally
    "k-NN (k=5)": (x_train, x_test),  # Pipeline handles scaling internally
    "Gradient Boosting": (x_train, x_test),
    "Naive Bayes": (x_train, x_test)
}

fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

for idx, (name, model) in enumerate(models.items()):
    X_tr, X_te = data_for_model[name]
    model.fit(X_tr, y_train)
    y_pred = model.predict(X_te)
    
    cm = confusion_matrix(y_test, y_pred)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    axes[idx].set_title(name)
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

for j in range(len(models), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()


print("\n--- Numeričke vrijednosti konfuzijskih matrica ---")
for name, model in models.items():
    X_tr, X_te = data_for_model[name]
    model.fit(X_tr, y_train)
    y_pred = model.predict(X_te)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print(f"\n{name}:")
    print(f"  True Negatives (Low correctly predicted): {tn}")
    print(f"  False Positives (Low predicted as High): {fp}")
    print(f"  False Negatives (High predicted as Low): {fn}")
    print(f"  True Positives (High correctly predicted): {tp}")
# Out:
# --- Numeričke vrijednosti konfuzijskih matrica ---
#
# Logistic Regression:
#   True Negatives (Low correctly predicted): 136
#   False Positives (Low predicted as High): 0
#   False Negatives (High predicted as Low): 8
#   True Positives (High correctly predicted): 84
#
# Decision Tree:
#   True Negatives (Low correctly predicted): 133
#   False Positives (Low predicted as High): 3
#   False Negatives (High predicted as Low): 1
#   True Positives (High correctly predicted): 91
#
# Random Forest:
#   True Negatives (Low correctly predicted): 136
#   False Positives (Low predicted as High): 0
#   False Negatives (High predicted as Low): 2
#   True Positives (High correctly predicted): 90
#
# SVM (RBF):
#   True Negatives (Low correctly predicted): 136
#   False Positives (Low predicted as High): 0
#   False Negatives (High predicted as Low): 5
#   True Positives (High correctly predicted): 87
#
# k-NN (k=5):
#   True Negatives (Low correctly predicted): 135
# ...

# %% [markdown]
# Decision Tree is prone to overfitting and is less stable on new data, while Gradient Boosting and Random Forest are more robust and provide a better balance across the entire test set.
#
# Decision Tree je sklon overfittingu i manje je stabilan na novim podacima, dok su Gradient Boosting i Random Forest robusniji i daju bolji balans na cijelom testnom skupu.

# %% [markdown]
# ## 5‑fold cross‑validation is crucial for assessing model stability and generalization, especially in medical applications.
# If a model performs excellently on the training set but poorly on cross‑validation, that is a sign of overfitting.
# Small standard deviations (±0.008) mean that the model is stable – it behaves consistently across different data subsets, which is crucial for medical applications.

# %% [markdown]
# 5-fold križna validacija je ključna za procjenu stabilnosti i generalizacije modela, posebno u medicinskim primjenama.
# Ako model ima odlične rezultate na trening skupu, ali loše na križnoj validaciji, to je znak overfittinga.
# Male standardne devijacije (±0.008) znače da je model stabilan – ponaša se dosljedno na različitim podskupovima podataka, što je ključno za medicinsku primjenu.

# %%
all_models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "Naive Bayes": GaussianNB(),
    "SVM (RBF)": Pipeline([('scaler', StandardScaler()), ('svm', SVC(probability=True, random_state=42))]),
    "k-NN (k=5)": Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier(n_neighbors=5))]),
    "XGBoost": XGBClassifier(n_estimators=100, random_state=42, use_label_encoder=False, eval_metric='logloss')
}


scoring = {
    'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'roc_auc': 'roc_auc'
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = []

for name, model in all_models.items():
    scores = cross_validate(model, x, y, cv=cv, scoring=scoring, 
                            return_train_score=False, n_jobs=-1)
    mean_scores = {f'mean_{m}': np.mean(scores[f'test_{m}']) for m in scoring}
    std_scores = {f'std_{m}': np.std(scores[f'test_{m}']) for m in scoring}
    results.append({
        'Model': name,
        **mean_scores,
        **std_scores
    })

results_df = pd.DataFrame(results)
results_df = results_df.round(4)

results_df = results_df.sort_values('mean_f1', ascending=False)

print("=== REZULTATI 5-FOLD KRIŽNE VALIDACIJE ===\n")
print(results_df[['Model', 'mean_accuracy', 'mean_precision', 'mean_recall', 'mean_f1', 'mean_roc_auc']])

best_model = results_df.iloc[0]
print(f"\n📌 Najbolji model po F1 score: {best_model['Model']}")
print(f"   F1 = {best_model['mean_f1']:.4f} ± {best_model['std_f1']:.4f}")
print(f"   Recall = {best_model['mean_recall']:.4f} ± {best_model['std_recall']:.4f}")
print(f"   AUC = {best_model['mean_roc_auc']:.4f} ± {best_model['std_roc_auc']:.4f}")
# Out:
# === REZULTATI 5-FOLD KRIŽNE VALIDACIJE ===
#
#                  Model  mean_accuracy  mean_precision  mean_recall  mean_f1  \
# 3    Gradient Boosting         0.9877          0.9849       0.9848   0.9848
# 7              XGBoost         0.9868          0.9808       0.9870   0.9838
# 2        Random Forest         0.9789          0.9644       0.9848   0.9744
# 6           k-NN (k=5)         0.9737          0.9633       0.9717   0.9675
# 5            SVM (RBF)         0.9711          0.9553       0.9739   0.9645
# 1        Decision Tree         0.9675          0.9490       0.9717   0.9601
# 0  Logistic Regression         0.9614          0.9542       0.9500   0.9519
# 4          Naive Bayes         0.9596          0.9561       0.9435   0.9496
#
#    mean_roc_auc
# 3        0.9992
# 7        0.9991
# 2        0.9988
# 6        0.9901
# 5        0.9977
# 1        0.9682
# 0        0.9951
# 4        0.9902
#
# 📌 Najbolji model po F1 score: Gradient Boosting
#    F1 = 0.9848 ± 0.0134
# ...

# %% [markdown]
# ## Gradient Boosting Feature Importance - Važnost značajki u Gradient Boosting modelu
#
# Feature importance reveals which variables contribute most to the model's predictions, which is crucial in medical applications to understand the risk factors driving the classification.

# %% [markdown]
# Značaj karakteristika otkriva koje varijable najviše doprinose predviđanjima modela, što je ključno u medicinskim primjenama kako bi se razumjeli faktori rizika koji upravljaju klasifikacijom.

# %%
# GRADIENT BOOSTING - Feature Importance vizualizacija sa gradijentom boja
# Ključni faktori koji doprinose predikciji rizika u trudnoći

from sklearn.ensemble import GradientBoostingClassifier

gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(x, y)

feature_importance_gb = pd.DataFrame({
    'Feature': x.columns,
    'Importance': gb_model.feature_importances_
}).sort_values('Importance', ascending=False)

# Dodaj kolonu za procentualnu vrijednost (za lakše ispisivanje) - Add a column for percentage value (for easier display)
feature_importance_gb['Importance_Pct'] = feature_importance_gb['Importance'] * 100

print("=" * 60)
print("GRADIENT BOOSTING - VAŽNOST ZNAČAJKI (Feature Importance)")
print("=" * 60)

print("\nZnačajke sortirane po važnosti:\n")
print(f"{'Feature':<30} {'Importance':>12} {'(%)':>8}")
print("-" * 50)
for idx, row in feature_importance_gb.iterrows():
    print(f"{row['Feature']:30s} {row['Importance']:>12.4f} {row['Importance_Pct']:>7.1f}%")

# Vizualizacija sa gradijentom boja (Plava skala za Gradient Boosting) - Visualization with color gradient (Blue scale for Gradient Boosting)
fig, ax = plt.subplots(figsize=(12, 6))

# Boje prema važnosti (tamnije plava = važnije) - Colors based on importance (darker blue = more important)
colors = plt.cm.Blues(feature_importance_gb['Importance'] / feature_importance_gb['Importance'].max())

bars = ax.barh(feature_importance_gb['Feature'], feature_importance_gb['Importance'], 
               color=colors, alpha=0.9, edgecolor='navy', linewidth=0.5)

# Dodaj vrijednosti na kraj svakog stupca - Add values at the end of each bar
for i, (bar, importance, pct) in enumerate(zip(bars, 
                                                feature_importance_gb['Importance'],
                                                feature_importance_gb['Importance_Pct'])):
    # Tekst na kraju stupca - Value at the end of the bar
    ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2, 
            f'{importance:.3f} ({pct:.1f}%)',
            va='center', ha='left', fontsize=9, fontweight='bold', color='navy')
    
    # Dodaj mali marker na kraj stupca - Add a small marker at the end of the bar
    ax.scatter(bar.get_width(), bar.get_y() + bar.get_height()/2, 
               color='darkblue', s=40, zorder=5, marker='D')

ax.set_xlabel('Importance Score', fontsize=12, fontweight='bold')
ax.set_ylabel('Feature', fontsize=12, fontweight='bold')
ax.set_title('Gradient Boosting - Važnost Značajki\n(Key factors contributing to pregnancy risk prediction)', 
             fontsize=14, fontweight='bold')
ax.invert_yaxis()
ax.grid(axis='x', alpha=0.3, linestyle='--')

# Dodaj legendu za boje - Add color legend
sm = plt.cm.ScalarMappable(cmap='Blues', 
                           norm=plt.Normalize(0, feature_importance_gb['Importance'].max()))
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
cbar.set_label('Relative Importance', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# ...
# GRADIENT BOOSTING - VAŽNOST ZNAČAJKI (Feature Importance)
# ...
#
# Značajke sortirane po važnosti:
#
# Feature                          Importance      (%)
# --------------------------------------------------
# dijabetes                            0.2556    25.6%
# glukoza_u_krvi                       0.1892    18.9%
# BMI                                  0.1803    18.0%
# gestacijski_dijabetes                0.1755    17.5%
# otkucaji_srca                        0.0911     9.1%
# mentalno_zdravlje                    0.0785     7.8%
# komplikacije_u_proslosti             0.0201     2.0%
# dob                                  0.0049     0.5%
# sistolicki_krvni_tlak                0.0038     0.4%
# dijastolicki_krvni_tlak              0.0008     0.1%
# tjelesna_temp                        0.0003     0.0%

# %% [markdown]
# ## Random Forest Feature Importance - Važnost značajki u Gradient Boosting modelu
#
# Feature importance reveals which variables contribute most to the model's predictions, which is crucial in medical applications to understand the risk factors driving the classification.

# %%
# Random Forest - Feature Importance vizualizacija sa gradijentom boja
# Ključni faktori koji doprinose predikciji rizika u trudnoći

rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, 
                                   min_samples_leaf=2, random_state=42, n_jobs=-1)
rf_model.fit(x, y)

feature_importance_rf = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)

# Dodaj kolonu za procentualnu vrijednost (za lakše ispisivanje) - Add a column for percentage value (for easier display)
feature_importance_rf['Importance_Pct'] = feature_importance_rf['Importance'] * 100

print("=" * 60)
print("RANDOM FOREST - VAŽNOST ZNAČAJKI (Feature Importance)")
print("=" * 60)

print("\nZnačajke sortirane po važnosti:\n")
print(f"{'Feature':<30} {'Importance':>12} {'(%)':>8}")
print("-" * 50)
for idx, row in feature_importance_rf.iterrows():
    print(f"{row['Feature']:30s} {row['Importance']:>12.4f} {row['Importance_Pct']:>7.1f}%")

# Vizualizacija sa gradijentom boja - Visualization with color gradient (Red-Orange scale for Random Forest)
fig, ax = plt.subplots(figsize=(12, 6))

# Boje prema važnosti (tamnije = važnije) - Colors based on importance (darker = more important)
colors = plt.cm.YlOrRd(feature_importance_rf['Importance'] / feature_importance_rf['Importance'].max())

bars = ax.barh(feature_importance_rf['Feature'], feature_importance_rf['Importance'], 
               color=colors, alpha=0.9, edgecolor='black', linewidth=0.5)

# Dodaj vrijednosti na kraj svakog stupca - Add values at the end of each bar
for i, (bar, importance, pct) in enumerate(zip(bars, 
                                                feature_importance_rf['Importance'],
                                                feature_importance_rf['Importance_Pct'])):
    # Tekst na kraju stupca - Value at the end of the bar
    ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2, 
            f'{importance:.3f} ({pct:.1f}%)',
            va='center', ha='left', fontsize=9, fontweight='bold')
    
    # Dodaj mali marker na kraj stupca - Add a small marker at the end of the bar
    ax.scatter(bar.get_width(), bar.get_y() + bar.get_height()/2, 
               color='darkred', s=40, zorder=5, marker='D')

ax.set_xlabel('Importance Score', fontsize=12, fontweight='bold')
ax.set_ylabel('Feature', fontsize=12, fontweight='bold')
ax.set_title('Random Forest - Važnost Značajki\n(Key factors contributing to pregnancy risk prediction)', 
             fontsize=14, fontweight='bold')
ax.invert_yaxis()
ax.grid(axis='x', alpha=0.3, linestyle='--')

# Dodaj legendu za boje - Add color legend
sm = plt.cm.ScalarMappable(cmap='YlOrRd', 
                           norm=plt.Normalize(0, feature_importance_rf['Importance'].max()))
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
cbar.set_label('Relative Importance', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# ...
# RANDOM FOREST - VAŽNOST ZNAČAJKI (Feature Importance)
# ...
#
# Značajke sortirane po važnosti:
#
# Feature                          Importance      (%)
# --------------------------------------------------
# dijabetes                            0.2262    22.6%
# glukoza_u_krvi                       0.2159    21.6%
# otkucaji_srca                        0.1464    14.6%
# BMI                                  0.1438    14.4%
# gestacijski_dijabetes                0.0959     9.6%
# mentalno_zdravlje                    0.0741     7.4%
# komplikacije_u_proslosti             0.0462     4.6%
# sistolicki_krvni_tlak                0.0170     1.7%
# dijastolicki_krvni_tlak              0.0151     1.5%
# dob                                  0.0141     1.4%
# tjelesna_temp                        0.0053     0.5%

# %%
print("\n" + "=" * 60)
print("POREĐENJE RANDOM FOREST vs GRADIENT BOOSTING")
print("=" * 60)

# Provjeri da li postoji feature_importance_rf (iz prethodne ćelije) - Check if feature_importance_rf exists (from the previous cell)
if 'feature_importance_rf' not in dir():
    print("\n⚠️ Upozorenje: feature_importance_rf nije pronađen.")
    print("   Prvo pokreni ćeliju za Random Forest vizualizaciju.")
else:
    # Uporedni bar chart - Comparative bar chart with color gradients for both models
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    
    # Random Forest (lijevo) - Zelena skala - Green scale for Random Forest
    colors_rf = plt.cm.Greens(feature_importance_rf['Importance'] / feature_importance_rf['Importance'].max())
    bars1 = ax1.barh(feature_importance_rf['Feature'], feature_importance_rf['Importance'], 
                     color=colors_rf, alpha=0.9, edgecolor='darkgreen', linewidth=0.5)
    
    for bar, imp, pct in zip(bars1, feature_importance_rf['Importance'], 
                              feature_importance_rf['Importance_Pct']):
        ax1.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2, 
                f'{imp:.3f} ({pct:.1f}%)', va='center', ha='left', fontsize=8)
    
    ax1.set_xlabel('Importance Score', fontsize=11, fontweight='bold')
    ax1.set_ylabel('Feature', fontsize=11, fontweight='bold')
    ax1.set_title('Random Forest', fontsize=12, fontweight='bold', color='darkgreen')
    ax1.invert_yaxis()
    ax1.grid(axis='x', alpha=0.3)
    
    # Gradient Boosting (desno) - Plava skala - Blue scale for Gradient Boosting
    colors_gb = plt.cm.Blues(feature_importance_gb['Importance'] / feature_importance_gb['Importance'].max())
    bars2 = ax2.barh(feature_importance_gb['Feature'], feature_importance_gb['Importance'], 
                     color=colors_gb, alpha=0.9, edgecolor='navy', linewidth=0.5)
    
    for bar, imp, pct in zip(bars2, feature_importance_gb['Importance'], 
                              feature_importance_gb['Importance_Pct']):
        ax2.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2, 
                f'{imp:.3f} ({pct:.1f}%)', va='center', ha='left', fontsize=8)
    
    ax2.set_xlabel('Importance Score', fontsize=11, fontweight='bold')
    ax2.set_ylabel('Feature', fontsize=11, fontweight='bold')
    ax2.set_title('Gradient Boosting', fontsize=12, fontweight='bold', color='navy')
    ax2.invert_yaxis()
    ax2.grid(axis='x', alpha=0.3)
    
    plt.suptitle('Poređenje Random Forest vs Gradient Boosting\nFeature Importance za predikciju rizika u trudnoći', 
                 fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    # TABELARNI PRIKAZ TOP 5 ZNAČAJKI - TABULAR DISPLAY OF TOP 5 FEATURES
    print("\n" + "=" * 60)
    print("TOP 5 NAJVAŽNIJIH ZNAČAJKI PO MODELIMA")
    print("=" * 60)
    
    # Kreiraj tabelu za poređenje - Create a table for comparison
    comparison_data = []
    rf_top5 = feature_importance_rf.head(5)
    gb_top5 = feature_importance_gb.head(5)
    
    print(f"\n{'Random Forest':<35} {'Gradient Boosting':<35}")
    print("-" * 70)
    
    for i in range(5):
        rf_feature = rf_top5.iloc[i]['Feature'] if i < len(rf_top5) else "-"
        rf_imp = rf_top5.iloc[i]['Importance'] if i < len(rf_top5) else 0
        rf_pct = rf_top5.iloc[i]['Importance_Pct'] if i < len(rf_top5) else 0
        
        gb_feature = gb_top5.iloc[i]['Feature'] if i < len(gb_top5) else "-"
        gb_imp = gb_top5.iloc[i]['Importance'] if i < len(gb_top5) else 0
        gb_pct = gb_top5.iloc[i]['Importance_Pct'] if i < len(gb_top5) else 0
        
        print(f"{i+1}. {rf_feature:<28} {rf_imp:.4f} ({rf_pct:.1f}%)    {i+1}. {gb_feature:<28} {gb_imp:.4f} ({gb_pct:.1f}%)")
    
    # PIE CHART ZA TOP 5 ZNAČAJKI (RANDOM FOREST) - PIE CHART FOR TOP 5 FEATURES (RANDOM FOREST) I GRADIENT BOOSTING
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    
    # Pie chart za Random Forest - Zelena skala - Green scale for Random Forest
    rf_top5_pie = feature_importance_rf.head(5).copy()
    rf_others_sum = feature_importance_rf.iloc[5:]['Importance'].sum()
    
    rf_pie_data = pd.concat([rf_top5_pie, 
                              pd.DataFrame({'Feature': ['Others'], 'Importance': [rf_others_sum]})])
    rf_pie_colors = ['#2ecc71', '#27ae60', '#1e8449', '#196f3d', '#145a32', '#7f8c8d']
    
    wedges1, texts1, autotexts1 = ax1.pie(rf_pie_data['Importance'], 
                                           labels=rf_pie_data['Feature'],
                                           autopct=lambda pct: f'{pct:.1f}%',
                                           colors=rf_pie_colors[:len(rf_pie_data)],
                                           explode=[0.03] * len(rf_pie_data),
                                           shadow=True,
                                           startangle=90)
    
    for autotext in autotexts1:
        autotext.set_color('white')
        autotext.set_fontweight('bold')
        autotext.set_fontsize(9)
    
    ax1.set_title('Random Forest - Top 5 značajki', fontsize=12, fontweight='bold', color='darkgreen')
    
    # Pie chart za Gradient Boosting - Plava skala - Blue scale for Gradient Boosting
    gb_top5_pie = feature_importance_gb.head(5).copy()
    gb_others_sum = feature_importance_gb.iloc[5:]['Importance'].sum()
    
    gb_pie_data = pd.concat([gb_top5_pie, 
                              pd.DataFrame({'Feature': ['Others'], 'Importance': [gb_others_sum]})])
    gb_pie_colors = ['#3498db', '#2980b9', '#2471a3', '#1f618d', '#1a5276', '#7f8c8d']
    
    wedges2, texts2, autotexts2 = ax2.pie(gb_pie_data['Importance'], 
                                           labels=gb_pie_data['Feature'],
                                           autopct=lambda pct: f'{pct:.1f}%',
                                           colors=gb_pie_colors[:len(gb_pie_data)],
                                           explode=[0.03] * len(gb_pie_data),
                                           shadow=True,
                                           startangle=90)
    
    for autotext in autotexts2:
        autotext.set_color('white')
        autotext.set_fontweight('bold')
        autotext.set_fontsize(9)
    
    ax2.set_title('Gradient Boosting - Top 5 značajki', fontsize=12, fontweight='bold', color='navy')
    
    plt.suptitle('Distribucija važnosti značajki - Top 5 vs Ostale', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

    # ZAKLJUČAK - CONCLUSION
    print("\n" + "=" * 60)
    print("ZAKLJUČAK ANALIZE")
    print("=" * 60)
    
    print("\n📌 Najvažnije značajke za predikciju rizika u trudnoći:")
    
    # Zajedničke značajke u top 3 oba modela - Common features in the top 3 of both models
    rf_top3 = set(feature_importance_rf.head(3)['Feature'])
    gb_top3 = set(feature_importance_gb.head(3)['Feature'])
    common_features = rf_top3.intersection(gb_top3)
    
    for feature in common_features:
        print(f"   {feature}")
    
    print("\n📌 Ključne razlike između modela:")
    print(f"   • Random Forest: Ravnomjernija raspodjela važnosti")
    print(f"   • Gradient Boosting: Veća koncentracija na najjaču značajku")
    
    print("\n📌 Preporuka:")
    if feature_importance_rf.iloc[0]['Feature'] == feature_importance_gb.iloc[0]['Feature']:
        top_feature = feature_importance_rf.iloc[0]['Feature']
        print(f"   • {top_feature} je najvažniji prediktor rizika (oba modela)")
    print("   • Za kliničku primjenu, Random Forest je robusniji izbor")
    print("   • Gradient Boosting daje veću težinu dominantnoj značajci")
# Out:
# ...
# POREĐENJE RANDOM FOREST vs GRADIENT BOOSTING
# ...
# TOP 5 NAJVAŽNIJIH ZNAČAJKI PO MODELIMA
# ...
#
# Random Forest                       Gradient Boosting
# ----------------------------------------------------------------------
# 1. dijabetes                    0.2262 (22.6%)    1. dijabetes                    0.2556 (25.6%)
# 2. glukoza_u_krvi               0.2159 (21.6%)    2. glukoza_u_krvi               0.1892 (18.9%)
# 3. otkucaji_srca                0.1464 (14.6%)    3. BMI                          0.1803 (18.0%)
# 4. BMI                          0.1438 (14.4%)    4. gestacijski_dijabetes        0.1755 (17.5%)
# 5. gestacijski_dijabetes        0.0959 (9.6%)    5. otkucaji_srca                0.0911 (9.1%)
# ...
# ZAKLJUČAK ANALIZE
# ...
#
# 📌 Najvažnije značajke za predikciju rizika u trudnoći:
#    glukoza_u_krvi
#    dijabetes
#
# 📌 Ključne razlike između modela:
#    • Random Forest: Ravnomjernija raspodjela važnosti
#    • Gradient Boosting: Veća koncentracija na najjaču značajku
#
# ...

# %% [markdown]
# ## Conclusion - zakljucak
# The Gradient Boosting model achieves near-perfect performance (F1 ≈ 0.985, AUC ≈ 0.999), with diabetes, blood glucose, and BMI being the most important predictors.

# %% [markdown]
# Model Gradient Boosting postiže gotovo savršene performanse (F1 ≈ 0,985, AUC ≈ 0,999), a najvažnije značajke su dijabetes, glukoza u krvi i BMI.

# %% [markdown]
# The Random Forest model achieves high predictive accuracy (≈97.8%), with diabetes (22.6%), blood glucose (21.6%), heart rate (14.6%), and BMI (14.4%) as the most important risk factors. Its balanced feature importance distribution makes it a robust and reliable choice for clinical pregnancy risk assessment.

# %% [markdown]
# Model Random Forest postiže visoku prediktivnu tačnost (≈97,8%), pri čemu su dijabetes (22,6%), glukoza u krvi (21,6%), otkucaji srca (14,6%) i ITM (14,4%) najvažniji faktori rizika. Njegova uravnotežena raspodjela važnosti značajki čini ga robusnim i pouzdanim izborom za kliničku procjenu rizika u trudnoći.

# %% [markdown]
# ## Recommendation
#
# Random Forest is recommended as the primary model for production deployment due to its:
#
#     Robustness against outliers and measurement errors
#
#     Better generalization capabilities
#
#     Faster training and inference times
#
#     Interpretable feature importance distribution

# %% [markdown]
# Preporuka
#
# Random Forest se preporučuje kao primarni model za produkcijsku primjenu zbog njegove:
#
#     Robusnosti na odstupanja i greške u mjerenju
#
#     Boljih mogućnosti generalizacije
#
#     Bržeg vremena treniranja i zaključivanja
#
#     Interpretabilne raspodjele važnosti značajki
